# %%
import pandas as pd

file_list = ["hasil_scrape_batikmahkota.xlsx", "hasil_scrape_batikkultur.xlsx", "hasil_scrape_batikdanarhadi_id.xlsx", "hasil_scrape_batikkerisonline.xlsx", "hasil_scrape_batikula.xlsx",
             "hasil_scrape_batikula.xlsx", "hasil_scrape_reels_lengkap_batikmahkotacom.xlsx", "hasil_scrape_reels_lengkap_batikkultur.xlsx",
        ]

df_list = [pd.read_excel(file) for file in file_list]

df_combined = pd.concat(df_list, ignore_index= True)

df_combined.to_excel('data_combined_batik_tekstil.xlsx', index=False)

print("Penggabungan selesai. File tersimpan sebagai: data_combined_batik_tekstil.xlsx")
# Out:
# Penggabungan selesai. File tersimpan sebagai: data_combined_batik_tekstil.xlsx
